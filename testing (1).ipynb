# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('e15.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Time_Start', 'Time_End', 'Location', 'Elephant_ID', 'Behavior',
#        'Duration', 'Food_Type', 'Heart_Rate', 'Weather_Condition',
#        'Is_Sleeping'],
#       dtype='object')

# %%
df.tail()
# Out:
#             Date Time_Start Time_End     Location Elephant_ID  Behavior  \
# 5495  2024-04-30      03:08    16:32    near lake        E009    Eating
# 5496  2024-04-30      04:09    08:19  Forest Area        E022  Sleeping
# 5497  2024-04-30      13:57    14:56    near lake        E002     Angry
# 5498  2024-04-30      07:45    23:24    Grassland        E017    Eating
# 5499  2024-04-30      03:22    20:43    near lake        E009     Angry
#
#       Duration Food_Type  Heart_Rate Weather_Condition Is_Sleeping
# 5495      16.0       Yes          83              Rain          No
# 5496       5.0        No         108             Windy         Yes
# 5497       1.7        No         124             Clear          No
# 5498      15.5       Yes          82             Windy          No
# 5499       1.6        No         122            Cloudy          No

# %%
df.shape
# Out:
# (5500, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               5500 non-null   object
#  1   Time_Start         5500 non-null   object
#  2   Time_End           5500 non-null   object
#  3   Location           5500 non-null   object
#  4   Elephant_ID        5500 non-null   object
#  5   Behavior           5500 non-null   object
#  6   Duration           5500 non-null   float64
#  7   Food_Type          5500 non-null   object
#  8   Heart_Rate         5500 non-null   int64
#  9   Weather_Condition  5500 non-null   object
#  10  Is_Sleeping        5500 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 472.8+ KB

# %%
df.isnull().sum()
# Out:
# Date                 0
# Time_Start           0
# Time_End             0
# Location             0
# Elephant_ID          0
# Behavior             0
# Duration             0
# Food_Type            0
# Heart_Rate           0
# Weather_Condition    0
# Is_Sleeping          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.select_dtypes('object').columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# Date
# 2024-04-23    60
# 2024-03-01    59
# 2024-04-01    59
# 2024-03-02    58
# 2024-01-30    58
#               ..
# 2024-03-23    34
# 2024-02-15    33
# 2024-04-25    33
# 2024-03-15    31
# 2024-02-20    30
# Name: count, Length: 121, dtype: int64
# ******************************
# Time_Start
# 00:06    17
# 02:50    15
# 01:58    15
# 02:47    13
# 09:14    13
#          ..
# 22:23     1
# 21:38     1
# 09:30     1
# 17:00     1
# 20:28     1
# Name: count, Length: 1263, dtype: int64
# ******************************
# Time_End
# 19:25    17
# 22:34    15
# 22:30    14
# 20:11    14
# 23:59    14
#          ..
# 06:40     1
# 10:08     1
# 09:22     1
# 17:41     1
# 03:12     1
# Name: count, Length: 1269, dtype: int64
# ******************************
# Location
# Forest Area    1140
# Forest Edge    1128
# Grassland      1093
# In lake        1070
# near lake      1069
# Name: count, dtype: int64
# ******************************
# Elephant_ID
# E015    211
# E016    210
# ...

# %%
df.describe(include = "object")
# Out:
#               Date Time_Start Time_End     Location Elephant_ID Behavior  \
# count         5500       5500     5500         5500        5500     5500
# unique         121       1263     1269            5          29        3
# top     2024-04-23      00:06    19:25  Forest Area        E015    Angry
# freq            60         17       17         1140         211     1838
#
#        Food_Type Weather_Condition Is_Sleeping
# count       5500              5500        5500
# unique         2                 4           2
# top           No             Clear          No
# freq        3670              1407        3668

# %%
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['Date', 'Time_Start', 'Time_End', 'Location', 'Elephant_ID', 'Behavior',
#        'Food_Type', 'Weather_Condition', 'Is_Sleeping'],
#       dtype='object')

# %%
for i in ['Date', 'Time_Start', 'Time_End', 'Location', 'Elephant_ID', 'Behavior',
       'Food_Type', 'Weather_Condition', 'Is_Sleeping']:
       sns.scatterplot(data = df , x=i,y='Behavior')
       plt.show()

# %%
for i in ['Date', 'Time_Start', 'Time_End', 'Location', 'Elephant_ID', 'Behavior',
       'Food_Type', 'Weather_Condition', 'Is_Sleeping']:
       sns.scatterplot(data = df , x=i,y='Food_Type')
       plt.show()

# %%
s=df.select_dtypes(include="number").corr()

# %%
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Date                 0
# Time_Start           0
# Time_End             0
# Location             0
# Elephant_ID          0
# Behavior             0
# Duration             0
# Food_Type            0
# Heart_Rate           0
# Weather_Condition    0
# Is_Sleeping          0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#             Date Time_Start Time_End     Location Elephant_ID  Behavior  \
# 0     2024-01-01      21:18    22:50      In lake        E022     Angry
# 1     2024-01-01      11:53    16:18    Grassland        E023    Eating
# 2     2024-01-01      09:35    13:07    near lake        E011    Eating
# 3     2024-01-01      01:22    02:35    Grassland        E013    Eating
# 4     2024-01-01      12:58    23:13    near lake        E020     Angry
# ...          ...        ...      ...          ...         ...       ...
# 5495  2024-04-30      03:08    16:32    near lake        E009    Eating
# 5496  2024-04-30      04:09    08:19  Forest Area        E022  Sleeping
# 5497  2024-04-30      13:57    14:56    near lake        E002     Angry
# 5498  2024-04-30      07:45    23:24    Grassland        E017    Eating
# 5499  2024-04-30      03:22    20:43    near lake        E009     Angry
#
#       Duration Food_Type  Heart_Rate Weather_Condition Is_Sleeping
# ...

# %%
df
# Out:
#             Date Time_Start Time_End     Location Elephant_ID  Behavior  \
# 0     2024-01-01      21:18    22:50      In lake        E022     Angry
# 1     2024-01-01      11:53    16:18    Grassland        E023    Eating
# 2     2024-01-01      09:35    13:07    near lake        E011    Eating
# 3     2024-01-01      01:22    02:35    Grassland        E013    Eating
# 4     2024-01-01      12:58    23:13    near lake        E020     Angry
# ...          ...        ...      ...          ...         ...       ...
# 5495  2024-04-30      03:08    16:32    near lake        E009    Eating
# 5496  2024-04-30      04:09    08:19  Forest Area        E022  Sleeping
# 5497  2024-04-30      13:57    14:56    near lake        E002     Angry
# 5498  2024-04-30      07:45    23:24    Grassland        E017    Eating
# 5499  2024-04-30      03:22    20:43    near lake        E009     Angry
#
#       Duration Food_Type  Heart_Rate Weather_Condition Is_Sleeping
# ...

# %%
dummy = pd.get_dummies(data = df,columns=['Date', 'Time_Start', 'Time_End', 'Location', 'Elephant_ID', 'Behavior',
       'Food_Type', 'Weather_Condition', 'Is_Sleeping'])

# %%
dummy
# Out:
#       Duration  Heart_Rate  Date_2024-01-01  Date_2024-01-02  Date_2024-01-03  \
# 0          1.7         123             True            False            False
# 1         17.3          89             True            False            False
# 2         17.8         110             True            False            False
# 3         17.3          91             True            False            False
# 4          1.7         132             True            False            False
# ...        ...         ...              ...              ...              ...
# 5495      16.0          83            False            False            False
# 5496       5.0         108            False            False            False
# 5497       1.7         124            False            False            False
# 5498      15.5          82            False            False            False
# 5499       1.6         122            False            False            False
#
# ...

# %%
dummy.describe()
# Out:
#           Duration   Heart_Rate
# count  5500.000000  5500.000000
# mean      7.165800   113.156000
# std       6.365841    19.372696
# min       1.000000    80.000000
# 25%       1.700000    97.000000
# 50%       4.100000   110.000000
# 75%      14.900000   128.000000
# max      18.000000   150.000000

# %%
dummy.describe().T
# Out:
#              count      mean        std   min   25%    50%    75%    max
# Duration    5500.0    7.1658   6.365841   1.0   1.7    4.1   14.9   18.0
# Heart_Rate  5500.0  113.1560  19.372696  80.0  97.0  110.0  128.0  150.0

# %%
dummy.hist()
# Out:
# array([[<Axes: title={'center': 'Duration'}>,
#         <Axes: title={'center': 'Heart_Rate'}>]], dtype=object)

# %%
for i in dummy.columns:
  if i == 'Behavior_Angry':
    sns.kdeplot(data=dummy,x=i)
    plt.show()

# %%
 dummy.columns
# Out:
# Index(['Duration', 'Heart_Rate', 'Date_2024-01-01', 'Date_2024-01-02',
#        'Date_2024-01-03', 'Date_2024-01-04', 'Date_2024-01-05',
#        'Date_2024-01-06', 'Date_2024-01-07', 'Date_2024-01-08',
#        ...
#        'Behavior_Eating', 'Behavior_Sleeping', 'Food_Type_No', 'Food_Type_Yes',
#        'Weather_Condition_Clear', 'Weather_Condition_Cloudy',
#        'Weather_Condition_Rain', 'Weather_Condition_Windy', 'Is_Sleeping_No',
#        'Is_Sleeping_Yes'],
#       dtype='object', length=2700)

# %%
 for i in ['Behavior_Eating', 'Behavior_Sleeping', 'Food_Type_No', 'Food_Type_Yes',
       'Weather_Condition_Clear', 'Weather_Condition_Cloudy',
       'Weather_Condition_Rain', 'Weather_Condition_Windy', 'Is_Sleeping_No',
       'Is_Sleeping_Yes']:
       sns.scatterplot(data=dummy,x=i,y='Behavior_Angry')
       plt.show()

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x= dummy.drop('Behavior_Angry',axis=1)
y=dummy['Behavior_Angry']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([9.99996640e-01, 3.88578059e-16, 1.73194792e-14, ...,
#        2.32036612e-14, 1.00000000e+00, 1.00000000e+00])

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
r2_score(y_test,y_predict)
# Out:
# 0.999999999979901

# %%
model.coef_
for i,j in zip(x_train.columns,model.coef_):
  print(f"{i}={j}")
# Out:
# Duration=2.2083522252072283e-15
# Heart_Rate=5.134781488891349e-16
# Date_2024-01-01=-2.83054698077545e-06
# Date_2024-01-02=-2.830546981691384e-06
# Date_2024-01-03=-2.8305469818717954e-06
# Date_2024-01-04=-2.8305469793946103e-06
# Date_2024-01-05=-2.8305469825483376e-06
# Date_2024-01-06=-2.8305469812941325e-06
# Date_2024-01-07=-2.8305469788932752e-06
# Date_2024-01-08=-2.830546979990054e-06
# Date_2024-01-09=-2.830546979681707e-06
# Date_2024-01-10=-2.830546982714871e-06
# Date_2024-01-11=-2.8305469835527425e-06
# Date_2024-01-12=-2.8305469842605097e-06
# Date_2024-01-13=-2.8305469816636286e-06
# Date_2024-01-14=-2.830546982884874e-06
# Date_2024-01-15=-2.8305469807069286e-06
# Date_2024-01-16=-2.830546979943867e-06
# Date_2024-01-17=-2.8305469806204364e-06
# Date_2024-01-18=-2.830546979468336e-06
# Date_2024-01-19=-2.8305469843507153e-06
# Date_2024-01-20=-2.8305469774087856e-06
# Date_2024-01-21=-2.8305469799488545e-06
# Date_2024-01-22=-2.830546982197056e-06
# ...

# %%
np.sqrt(mean_squared_error(y_test,y_predict))
# Out:
# 2.096497706086544e-06

# %%
y_test.mean()
# Out:
# 0.32303030303030306

# %%
2.096497706086544e-06/0.32303030303030306
# Out:
# 6.490096088260408e-06

# %%
residual=y_test-y_predict

# %%
residual.mean()
# Out:
# -6.726962564294934e-08

# %%
sns.kdeplot(residual)
residual.skew()
# Out:
# 0.0

# %%
sns.scatterplot(x=y_test,y=residual)
# Out:
# <Axes: xlabel='Behavior_Angry', ylabel='Behavior_Angry'>
